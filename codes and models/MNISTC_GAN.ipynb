# %%
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import imageio
import tensorflow as tf
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.optimizers import Adam
from keras.layers import Dense, Conv2D, MaxPooling2D,Flatten, Reshape, Dropout, BatchNormalization,LeakyReLU, Conv2DTranspose, ReLU
from matplotlib import pyplot as plt
import numpy as np
import numpy
from numpy import cov
from numpy import trace
from numpy import iscomplexobj
from numpy import asarray
from numpy.random import shuffle
from scipy.linalg import sqrtm
import random
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from keras.datasets.mnist import load_data
from skimage.transform import resize
import math
import os
from tensorflow.python.client import device_lib
import time
cross_entropy = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 6738213430997960656
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 5757075456
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 8744874134372957373
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
#  xla_global_id: 416903419]

# %%
# useful class and functions
def discriminator_loss(real_output, fake_output):
    real_loss = cross_entropy(tf.ones_like(real_output), real_output)
    fake_loss = cross_entropy(tf.zeros_like(fake_output), fake_output)
    total_loss = real_loss + fake_loss
    return total_loss
def generator_loss(fake_output):
    return cross_entropy(tf.ones_like(fake_output), fake_output)
class UnconditionalGAN(keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super(UnconditionalGAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim
        self.gen_loss_tracker = keras.metrics.Mean(name="generator_loss")
        self.disc_loss_tracker = keras.metrics.Mean(name="discriminator_loss")

    @property
    def metrics(self):
        return [self.gen_loss_tracker, self.disc_loss_tracker]

    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super(UnconditionalGAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn

    def train_step(self, data):
        real_images, one_hot_labels = data
        batch_size = tf.shape(real_images)[0]
        noise = tf.random.normal([batch_size, self.latent_dim])

        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            generated_images = self.generator(noise, training=True)

            real_output = self.discriminator(real_images, training=True)
            fake_output = self.discriminator(generated_images, training=True)

            gen_loss = generator_loss(fake_output)
            disc_loss = discriminator_loss(real_output, fake_output)

        gradients_of_generator = gen_tape.gradient(gen_loss, self.generator.trainable_variables)
        gradients_of_discriminator = disc_tape.gradient(disc_loss, self.discriminator.trainable_variables)

        self.g_optimizer.apply_gradients(zip(gradients_of_generator, self.generator.trainable_variables))
        self.d_optimizer.apply_gradients(zip(gradients_of_discriminator, self.discriminator.trainable_variables))
        self.gen_loss_tracker.update_state(gen_loss)
        self.disc_loss_tracker.update_state(disc_loss)
        return {
            "g_loss": self.gen_loss_tracker.result(),
            "d_loss": self.disc_loss_tracker.result(),
        }

def build_train_unconditional_gan(latent_dim):
    start_time = time.time()
    generator_in_channels = latent_dim
    discriminator_in_channels = 1
    discriminator = keras.Sequential(
        [
            keras.layers.InputLayer((28, 28, discriminator_in_channels)),
            layers.Conv2D(64, (3, 3), strides=(2, 2), padding="same"),
            layers.LeakyReLU(alpha=0.2),
            layers.Conv2D(128, (3, 3), strides=(2, 2), padding="same"),
            layers.LeakyReLU(alpha=0.2),
            layers.GlobalMaxPooling2D(),
            layers.Dense(1),
        ],
        name="discriminator",
    )
    # Create the generator.
    generator = keras.Sequential(
        [
            keras.layers.InputLayer((generator_in_channels,)),
            # We want to generate 128 + num_classes coefficients to reshape into a
            # 7x7x(128 + num_classes) map.
            layers.Dense(7 * 7 * generator_in_channels),
            layers.LeakyReLU(alpha=0.2),
            layers.Reshape((7, 7, generator_in_channels)),
            layers.Conv2DTranspose(128, (4, 4), strides=(2, 2), padding="same"),
            layers.LeakyReLU(alpha=0.2),
            layers.Conv2DTranspose(128, (4, 4), strides=(2, 2), padding="same"),
            layers.LeakyReLU(alpha=0.2),
            layers.Conv2D(1, (7, 7), padding="same", activation="sigmoid"),
        ],
        name="generator",
    )
    uncond_gan = UnconditionalGAN(
        discriminator=discriminator, generator=generator, latent_dim=latent_dim
    )
    uncond_gan.compile(
        d_optimizer=keras.optimizers.Adam(learning_rate=0.0001),
        g_optimizer=keras.optimizers.Adam(learning_rate=0.0001),
        loss_fn=keras.losses.BinaryCrossentropy(from_logits=True),
    )

    uncond_gan.fit(dataset, epochs=20, verbose = 0)
    end_time = time.time()
    print(f'Time for training GAN model: {round(end_time-start_time,2)} seconds')
    return uncond_gan.generator
class ConditionalGAN(keras.Model):
    def __init__(self, discriminator, generator, latent_dim):
        super(ConditionalGAN, self).__init__()
        self.discriminator = discriminator
        self.generator = generator
        self.latent_dim = latent_dim
        self.gen_loss_tracker = keras.metrics.Mean(name="generator_loss")
        self.disc_loss_tracker = keras.metrics.Mean(name="discriminator_loss")

    @property
    def metrics(self):
        return [self.gen_loss_tracker, self.disc_loss_tracker]

    def compile(self, d_optimizer, g_optimizer, loss_fn):
        super(ConditionalGAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_fn = loss_fn

    def train_step(self, data):
        # Unpack the data.
        real_images, one_hot_labels = data

        # Add dummy dimensions to the labels so that they can be concatenated with
        # the images. This is for the discriminator.
        image_one_hot_labels = one_hot_labels[:, :, None, None]
        image_one_hot_labels = tf.repeat(
            image_one_hot_labels, repeats=[image_size * image_size]
        )
        image_one_hot_labels = tf.reshape(
            image_one_hot_labels, (-1, image_size, image_size, num_classes)
        )

        # Sample random points in the latent space and concatenate the labels.
        # This is for the generator.
        batch_size = tf.shape(real_images)[0]
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        random_vector_labels = tf.concat(
            [random_latent_vectors, one_hot_labels], axis=1
        )

        # Decode the noise (guided by labels) to fake images.
        generated_images = self.generator(random_vector_labels)

        # Combine them with real images. Note that we are concatenating the labels
        # with these images here.
        fake_image_and_labels = tf.concat([generated_images, image_one_hot_labels], -1)
        real_image_and_labels = tf.concat([real_images, image_one_hot_labels], -1)
        combined_images = tf.concat(
            [fake_image_and_labels, real_image_and_labels], axis=0
        )

        # Assemble labels discriminating real from fake images.
        labels = tf.concat(
            [tf.ones((batch_size, 1)), tf.zeros((batch_size, 1))], axis=0
        )

        # Train the discriminator.
        with tf.GradientTape() as tape:
            predictions = self.discriminator(combined_images)
            d_loss = self.loss_fn(labels, predictions)
        grads = tape.gradient(d_loss, self.discriminator.trainable_weights)
        self.d_optimizer.apply_gradients(
            zip(grads, self.discriminator.trainable_weights)
        )

        # Sample random points in the latent space.
        random_latent_vectors = tf.random.normal(shape=(batch_size, self.latent_dim))
        random_vector_labels = tf.concat(
            [random_latent_vectors, one_hot_labels], axis=1
        )

        # Assemble labels that say "all real images".
        misleading_labels = tf.zeros((batch_size, 1))

        # Train the generator (note that we should *not* update the weights
        # of the discriminator)!
        with tf.GradientTape() as tape:
            fake_images = self.generator(random_vector_labels)
            fake_image_and_labels = tf.concat([fake_images, image_one_hot_labels], -1)
            predictions = self.discriminator(fake_image_and_labels)
            g_loss = self.loss_fn(misleading_labels, predictions)
        grads = tape.gradient(g_loss, self.generator.trainable_weights)
        self.g_optimizer.apply_gradients(zip(grads, self.generator.trainable_weights))

        # Monitor loss.
        self.gen_loss_tracker.update_state(g_loss)
        self.disc_loss_tracker.update_state(d_loss)
        return {
            "g_loss": self.gen_loss_tracker.result(),
            "d_loss": self.disc_loss_tracker.result(),
        }
def build_train_gan(latent_dim):
    start_time = time.time()
    generator_in_channels = latent_dim + num_classes
    discriminator_in_channels = num_channels + num_classes
    discriminator = keras.Sequential(
        [
            keras.layers.InputLayer((28, 28, discriminator_in_channels)),
            layers.Conv2D(64, (3, 3), strides=(2, 2), padding="same"),
            layers.LeakyReLU(alpha=0.2),
            layers.Conv2D(128, (3, 3), strides=(2, 2), padding="same"),
            layers.LeakyReLU(alpha=0.2),
            layers.GlobalMaxPooling2D(),
            layers.Dense(1),
        ],
        name="discriminator",
    )
    # Create the generator.
    generator = keras.Sequential(
        [
            keras.layers.InputLayer((generator_in_channels,)),
            # We want to generate 128 + num_classes coefficients to reshape into a
            # 7x7x(128 + num_classes) map.
            layers.Dense(7 * 7 * generator_in_channels),
            layers.LeakyReLU(alpha=0.2),
            layers.Reshape((7, 7, generator_in_channels)),
            layers.Conv2DTranspose(128, (4, 4), strides=(2, 2), padding="same"),
            layers.LeakyReLU(alpha=0.2),
            layers.Conv2DTranspose(128, (4, 4), strides=(2, 2), padding="same"),
            layers.LeakyReLU(alpha=0.2),
            layers.Conv2D(1, (7, 7), padding="same", activation="sigmoid"),
        ],
        name="generator",
    )
    cond_gan = ConditionalGAN(
        discriminator=discriminator, generator=generator, latent_dim=latent_dim
    )
    cond_gan.compile(
        d_optimizer=keras.optimizers.Adam(learning_rate=0.0003),
        g_optimizer=keras.optimizers.Adam(learning_rate=0.0003),
        loss_fn=keras.losses.BinaryCrossentropy(from_logits=True),
    )

    cond_gan.fit(dataset, epochs=20, verbose = 0)
    end_time = time.time()
    print(f'Time for training GAN model: {round(end_time-start_time,2)} seconds')
    return cond_gan.generator
    
def scale_images(images, new_shape):
    images_list = list()
    for image in images:
        # resize with nearest neighbor interpolation
        new_image = resize(image, new_shape, 0)
        # store
        images_list.append(new_image)
    return asarray(images_list)
 
# calculate frechet inception distance
def calculate_fid(model, images1, images2):
    # calculate activations
    act1 = model.predict(images1)
    act2 = model.predict(images2)
    # calculate mean and covariance statistics
    mu1, sigma1 = act1.mean(axis=0), cov(act1, rowvar=False)
    mu2, sigma2 = act2.mean(axis=0), cov(act2, rowvar=False)
    # calculate sum squared difference between means
    ssdiff = numpy.sum((mu1 - mu2)**2.0)
    # calculate sqrt of product between cov
    covmean = sqrtm(sigma1.dot(sigma2))
    # check and correct imaginary numbers from sqrt
    if iscomplexobj(covmean):
        covmean = covmean.real
    # calculate score
    fid = ssdiff + trace(sigma1 + sigma2 - 2.0 * covmean)
    return fid
def gen_fake_imgs(model, total_imgs, latent_dim):
    final_imgs = []
    #seed = tf.random.normal(shape=(total_imgs, latent_dim))
    random_latent_vectors = tf.random.normal(shape=(total_imgs, latent_dim))
    random_labels = []
    for i in range(total_imgs):
        random_labels.append(random.randint(0,9))
    one_hot_labels = keras.utils.to_categorical(random_labels, 10)
    seed = tf.concat(
            [random_latent_vectors, one_hot_labels], axis=1
        )
    batch_size = 32
    total_batch = math.ceil(total_imgs/32)
    for batch_index in range(total_batch):
        if (batch_index+1)*batch_size < total_imgs:
            batch_seed = seed[batch_index*batch_size:(batch_index+1)*batch_size]
        else:
            batch_seed = seed[batch_index*batch_size:]
        
        gen_imgs = model(batch_seed)
        final_imgs.append(gen_imgs)
    array = np.concatenate(final_imgs, axis = 0)
    array = tf.convert_to_tensor(array)
    return array
def gen_fake_imgs_uncond(model, total_imgs, latent_dim):
    final_imgs = []
    #seed = tf.random.normal(shape=(total_imgs, latent_dim))
    seed = tf.random.normal(shape=(total_imgs, latent_dim))
    
    batch_size = 32
    total_batch = math.ceil(total_imgs/32)
    for batch_index in range(total_batch):
        if (batch_index+1)*batch_size < total_imgs:
            batch_seed = seed[batch_index*batch_size:(batch_index+1)*batch_size]
        else:
            batch_seed = seed[batch_index*batch_size:]
        
        gen_imgs = model(batch_seed)
        final_imgs.append(gen_imgs)
    array = np.concatenate(final_imgs, axis = 0)
    array = tf.convert_to_tensor(array)
    return array

def preprocess_imgs(input_imgs):
    input_imgs = np.array(input_imgs).astype('float16')
    input_imgs = scale_images(input_imgs, (75,75,3))
    return input_imgs

def run_a_experiment_with_fixed_dim(latent_dim,inception_model, true_images):
    gan_fix_dim = build_train_gan(latent_dim)
    fake_imgs = gen_fake_imgs(gan_fix_dim, 10000,latent_dim)
    fake_imgs = preprocess_imgs(fake_imgs)
    fid_score = calculate_fid(inception_model, fake_imgs,true_images)
    return(fid_score)

def run_a_experiment_with_uncond_GAN(latent_dim,inception_model, true_images):
    gan_fix_dim = build_train_unconditional_gan(latent_dim)
    fake_imgs = gen_fake_imgs_uncond(gan_fix_dim, 10000,latent_dim)
    fake_imgs = preprocess_imgs(fake_imgs)
    fid_score = calculate_fid(inception_model, fake_imgs,true_images)
    return(fid_score)

# %%
# global parameters 
batch_size = 64
num_channels = 1
num_classes = 10
image_size = 28
# load data set
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()
all_digits = np.concatenate([x_train, x_test])
all_labels = np.concatenate([y_train, y_test])

all_digits = all_digits.astype("float32") / 255.0
all_digits = np.reshape(all_digits, (-1, 28, 28, 1))
all_labels = keras.utils.to_categorical(all_labels, 10)

# Create tf.data.Dataset.
dataset = tf.data.Dataset.from_tensor_slices((all_digits, all_labels))
dataset = dataset.shuffle(buffer_size=1024).batch(batch_size)

print(f"Shape of training images: {all_digits.shape}")
print(f"Shape of training labels: {all_labels.shape}")
# Out:
# Shape of training images: (70000, 28, 28, 1)
# Shape of training labels: (70000, 10)

# %%
# start running experiment
true_images = []
for img_batch in dataset:
    true_images.append(img_batch[0])
true_images = tf.concat(true_images, axis = 0)
true_images = preprocess_imgs(true_images[:10000]) # select 10000 imgs from calculating fid score

# load inception model
inception_model = InceptionV3(include_top=False, pooling='avg', input_shape=(75,75,3))

# %%
# to save experiment time, latent dim increased by 2
fid_scores = []
for i in range(0,129):
    if i%2 == 0:
        print('-'*60)
        print(f'current experiment latent dim: {i}')
        start_time = time.time()
        fid_score = run_a_experiment_with_fixed_dim(i,inception_model,true_images)
        end_time = time.time()
        print(f'time used for whole experiment: {round(end_time-start_time,2)} seconds')
        print(f'current id score = {fid_score}')
        fid_scores.append(fid_score)
# Out:
# ------------------------------------------------------------
# current experiment latent dim: 0
# Time for training GAN model: 322.44 seconds
# time used for whole experiment: 341.14 seconds
# current id score = 799.4979095361517
# ------------------------------------------------------------
# current experiment latent dim: 2
# Time for training GAN model: 326.27 seconds
# time used for whole experiment: 343.03 seconds
# current id score = 165.94651909571067
# ------------------------------------------------------------
# current experiment latent dim: 4
# Time for training GAN model: 325.75 seconds
# time used for whole experiment: 343.99 seconds
# current id score = 113.27242819303851
# ------------------------------------------------------------
# current experiment latent dim: 6
# Time for training GAN model: 329.75 seconds
# time used for whole experiment: 348.01 seconds
# current id score = 87.88192511446834
# ------------------------------------------------------------
# current experiment latent dim: 8
# Time for training GAN model: 326.65 seconds
# time used for whole experiment: 343.91 seconds
# current id score = 114.50836221026572
# ------------------------------------------------------------
# current experiment latent dim: 10
# Time for training GAN model: 327.11 seconds
# time used for whole experiment: 345.31 seconds
# current id score = 53.41335667580587
# ------------------------------------------------------------
# current experiment latent dim: 12
# Time for training GAN model: 330.24 seconds
# time used for whole experiment: 347.61 seconds
# current id score = 58.663190487063744
# ------------------------------------------------------------
# current experiment latent dim: 14
# Time for training GAN model: 330.17 seconds
# time used for whole experiment: 347.67 seconds
# current id score = 81.60396298179283
# ------------------------------------------------------------
# current experiment latent dim: 16
# Time for training GAN model: 333.9 seconds
# time used for whole experiment: 352.4 seconds
# current id score = 67.7932504234339
# ------------------------------------------------------------
# current experiment latent dim: 18
# Time for training GAN model: 330.42 seconds
# time used for whole experiment: 348.62 seconds
# current id score = 46.07572924949645
# ------------------------------------------------------------
# current experiment latent dim: 20
# Time for training GAN model: 331.45 seconds
# time used for whole experiment: 349.82 seconds
# current id score = 40.89024361939443
# ------------------------------------------------------------
# current experiment latent dim: 22
# Time for training GAN model: 331.51 seconds
# time used for whole experiment: 350.11 seconds
# current id score = 99.70101046977241
# ------------------------------------------------------------
# current experiment latent dim: 24
# Time for training GAN model: 333.02 seconds
# time used for whole experiment: 351.19 seconds
# current id score = 99.12377875857038
# ------------------------------------------------------------
# current experiment latent dim: 26
# Time for training GAN model: 349.44 seconds
# time used for whole experiment: 367.95 seconds
# current id score = 111.70149578153314
# ------------------------------------------------------------
# current experiment latent dim: 28
# Time for training GAN model: 351.23 seconds
# time used for whole experiment: 369.79 seconds
# current id score = 82.59188860298062
# ------------------------------------------------------------
# current experiment latent dim: 30
# Time for training GAN model: 347.86 seconds
# time used for whole experiment: 366.31 seconds
# current id score = 51.559214174003245
# ------------------------------------------------------------
# current experiment latent dim: 32
# Time for training GAN model: 354.01 seconds
# time used for whole experiment: 372.76 seconds
# current id score = 60.7873686303382
# ------------------------------------------------------------
# current experiment latent dim: 34
# Time for training GAN model: 366.49 seconds
# time used for whole experiment: 388.81 seconds
# current id score = 37.671374348705996
# ------------------------------------------------------------
# current experiment latent dim: 36
# Time for training GAN model: 419.08 seconds
# time used for whole experiment: 440.95 seconds
# current id score = 77.26602536654262
# ------------------------------------------------------------
# current experiment latent dim: 38
# Time for training GAN model: 422.6 seconds
# time used for whole experiment: 441.96 seconds
# current id score = 58.0724779864494
# ------------------------------------------------------------
# current experiment latent dim: 40
# Time for training GAN model: 361.61 seconds
# time used for whole experiment: 380.87 seconds
# current id score = 71.29035071148287
# ------------------------------------------------------------
# current experiment latent dim: 42
# Time for training GAN model: 399.09 seconds
# time used for whole experiment: 420.31 seconds
# current id score = 48.60413464281703
# ------------------------------------------------------------
# current experiment latent dim: 44
# Time for training GAN model: 398.88 seconds
# time used for whole experiment: 420.08 seconds
# current id score = 33.78614762493721
# ------------------------------------------------------------
# current experiment latent dim: 46
# Time for training GAN model: 391.75 seconds
# time used for whole experiment: 413.16 seconds
# current id score = 65.42726785100602
# ------------------------------------------------------------
# current experiment latent dim: 48
# Time for training GAN model: 374.3 seconds
# time used for whole experiment: 393.52 seconds
# current id score = 48.135399626297556
# ------------------------------------------------------------
# current experiment latent dim: 50
# Time for training GAN model: 387.12 seconds
# time used for whole experiment: 408.48 seconds
# current id score = 59.77396845885016
# ------------------------------------------------------------
# current experiment latent dim: 52
# Time for training GAN model: 388.88 seconds
# time used for whole experiment: 410.36 seconds
# current id score = 29.87063636577804
# ------------------------------------------------------------
# current experiment latent dim: 54
# Time for training GAN model: 395.94 seconds
# time used for whole experiment: 417.46 seconds
# current id score = 80.67032631154969
# ------------------------------------------------------------
# current experiment latent dim: 56
# Time for training GAN model: 400.49 seconds
# time used for whole experiment: 420.26 seconds
# current id score = 35.631754550758465
# ------------------------------------------------------------
# current experiment latent dim: 58
# Time for training GAN model: 383.04 seconds
# time used for whole experiment: 403.21 seconds
# current id score = 83.77145359658505
# ------------------------------------------------------------
# current experiment latent dim: 60
# Time for training GAN model: 406.93 seconds
# time used for whole experiment: 428.73 seconds
# current id score = 33.04594434260994
# ------------------------------------------------------------
# current experiment latent dim: 62
# Time for training GAN model: 406.31 seconds
# time used for whole experiment: 426.69 seconds
# current id score = 74.88836921369808
# ------------------------------------------------------------
# current experiment latent dim: 64
# Time for training GAN model: 408.98 seconds
# time used for whole experiment: 430.52 seconds
# current id score = 34.3364272745741
# ------------------------------------------------------------
# current experiment latent dim: 66
# Time for training GAN model: 404.0 seconds
# time used for whole experiment: 425.75 seconds
# current id score = 36.50810736286779
# ------------------------------------------------------------
# current experiment latent dim: 68
# Time for training GAN model: 409.78 seconds
# time used for whole experiment: 430.39 seconds
# current id score = 76.03732331988033
# ------------------------------------------------------------
# current experiment latent dim: 70
# Time for training GAN model: 438.74 seconds
# time used for whole experiment: 460.7 seconds
# current id score = 47.98340690588732
# ------------------------------------------------------------
# current experiment latent dim: 72
# Time for training GAN model: 428.35 seconds
# time used for whole experiment: 448.65 seconds
# current id score = 56.454003220096936
# ------------------------------------------------------------
# current experiment latent dim: 74
# Time for training GAN model: 423.3 seconds
# time used for whole experiment: 444.87 seconds
# current id score = 46.30285094952741
# ------------------------------------------------------------
# current experiment latent dim: 76
# Time for training GAN model: 419.69 seconds
# time used for whole experiment: 441.81 seconds
# current id score = 119.73576474282359
# ------------------------------------------------------------
# current experiment latent dim: 78
# Time for training GAN model: 424.64 seconds
# time used for whole experiment: 444.88 seconds
# current id score = 119.46517274149286
# ------------------------------------------------------------
# current experiment latent dim: 80
# Time for training GAN model: 377.09 seconds
# time used for whole experiment: 398.61 seconds
# current id score = 34.9703547568129
# ------------------------------------------------------------
# current experiment latent dim: 82
# Time for training GAN model: 432.16 seconds
# time used for whole experiment: 453.51 seconds
# current id score = 57.49690419495247
# ------------------------------------------------------------
# current experiment latent dim: 84
# Time for training GAN model: 419.69 seconds
# time used for whole experiment: 441.25 seconds
# current id score = 50.252521356190414
# ------------------------------------------------------------
# current experiment latent dim: 86
# Time for training GAN model: 412.65 seconds
# time used for whole experiment: 432.81 seconds
# current id score = 51.77848151882301
# ------------------------------------------------------------
# current experiment latent dim: 88
# Time for training GAN model: 425.8 seconds
# time used for whole experiment: 447.29 seconds
# current id score = 101.23157287968584
# ------------------------------------------------------------
# current experiment latent dim: 90
# Time for training GAN model: 418.35 seconds
# time used for whole experiment: 440.28 seconds
# current id score = 33.641074899426854
# ------------------------------------------------------------
# current experiment latent dim: 92
# Time for training GAN model: 401.29 seconds
# time used for whole experiment: 419.69 seconds
# current id score = 40.651616233776
# ------------------------------------------------------------
# current experiment latent dim: 94
# Time for training GAN model: 439.38 seconds
# time used for whole experiment: 461.89 seconds
# current id score = 37.32625816629171
# ------------------------------------------------------------
# current experiment latent dim: 96
# Time for training GAN model: 447.88 seconds
# time used for whole experiment: 469.21 seconds
# current id score = 39.83723099221439
# ------------------------------------------------------------
# current experiment latent dim: 98
# Time for training GAN model: 417.23 seconds
# time used for whole experiment: 439.3 seconds
# current id score = 66.24214664073702
# ------------------------------------------------------------
# current experiment latent dim: 100
# Time for training GAN model: 430.09 seconds
# time used for whole experiment: 452.16 seconds
# current id score = 91.07343337355744
# ------------------------------------------------------------
# current experiment latent dim: 102
# Time for training GAN model: 406.6 seconds
# time used for whole experiment: 425.61 seconds
# current id score = 26.190682796529565
# ------------------------------------------------------------
# current experiment latent dim: 104
# Time for training GAN model: 428.68 seconds
# time used for whole experiment: 451.35 seconds
# current id score = 78.83571770097348
# ------------------------------------------------------------
# current experiment latent dim: 106
# Time for training GAN model: 442.05 seconds
# time used for whole experiment: 463.53 seconds
# current id score = 28.328485952558232
# ------------------------------------------------------------
# current experiment latent dim: 108
# Time for training GAN model: 365.34 seconds
# time used for whole experiment: 384.22 seconds
# current id score = 49.95417325467336
# ------------------------------------------------------------
# current experiment latent dim: 110
# Time for training GAN model: 354.67 seconds
# time used for whole experiment: 372.5 seconds
# current id score = 78.160963007209
# ------------------------------------------------------------
# current experiment latent dim: 112
# Time for training GAN model: 345.33 seconds
# time used for whole experiment: 362.25 seconds
# current id score = 42.1798322522896
# ------------------------------------------------------------
# current experiment latent dim: 114
# Time for training GAN model: 338.98 seconds
# time used for whole experiment: 357.02 seconds
# current id score = 55.33377829517282
# ------------------------------------------------------------
# current experiment latent dim: 116
# Time for training GAN model: 345.9 seconds
# time used for whole experiment: 364.09 seconds
# current id score = 40.44331407740865
# ------------------------------------------------------------
# current experiment latent dim: 118
# Time for training GAN model: 358.42 seconds
# time used for whole experiment: 378.79 seconds
# current id score = 52.8139073023293
# ------------------------------------------------------------
# current experiment latent dim: 120
# Time for training GAN model: 361.54 seconds
# time used for whole experiment: 380.14 seconds
# current id score = 75.29076269200527
# ------------------------------------------------------------
# current experiment latent dim: 122
# Time for training GAN model: 354.02 seconds
# time used for whole experiment: 373.02 seconds
# current id score = 68.15945284299998
# ------------------------------------------------------------
# current experiment latent dim: 124
# Time for training GAN model: 357.45 seconds
# time used for whole experiment: 375.95 seconds
# current id score = 47.54035126647689
# ------------------------------------------------------------
# current experiment latent dim: 126
# Time for training GAN model: 346.85 seconds
# time used for whole experiment: 364.99 seconds
# current id score = 49.994299520349074
# ------------------------------------------------------------
# current experiment latent dim: 128
# Time for training GAN model: 353.91 seconds
# time used for whole experiment: 371.79 seconds
# current id score = 64.38755238038145

# %%
# start plot
import pandas as pd
#table = pd.DataFrame({
#    'fid_score':fid_scores
#})
#table.to_csv('fid_list.csv')
# load result
table = pd.read_csv('fid_list.csv')
fid_scores = table['fid_score']

# %%
# calculate fid score between true images and true images
true_images = []
for index,img_batch in enumerate(dataset):
    true_images.append(img_batch[0])
true_images = tf.concat(true_images, axis = 0)
true_images_batches = [true_images[0:10000], 
                      true_images[10000:20000],
                      true_images[20000:30000]]
fid_socre_between_true = []
for i in range(len(true_images_batches)-1):
    first_batch = preprocess_imgs(true_images_batches[i])
    second_batch = preprocess_imgs(true_images_batches[i+1])
    fid_score = calculate_fid(inception_model, first_batch,second_batch)
    fid_socre_between_true.append(fid_score)

# %%
plt.plot(range(0,129,2), fid_scores,c = 'g' ,label = 'CGan generated FID')
plt.axhline(np.mean(fid_socre_between_true), color = 'r', label = 'True Image FID')
plt.title('Latent dim and FID score')
plt.xlabel('Latent dim')
plt.ylabel('FID score')
plt.legend()
plt.show()

# %%
# start running experiment
true_images = []
for img_batch in dataset:
    true_images.append(img_batch[0])
true_images = tf.concat(true_images, axis = 0)
true_images = preprocess_imgs(true_images[:10000]) # select 10000 imgs from calculating fid score

# load inception model
inception_model = InceptionV3(include_top=False, pooling='avg', input_shape=(75,75,3))
# experiment for unconditional GAN
# to save experiment time, latent dim increased by 2
Uncond_fid_scores = []
for i in range(1,129):
    if i%2 == 0 or i==1:
        print('-'*60)
        print(f'current experiment latent dim: {i}')
        start_time = time.time()
        fid_score = run_a_experiment_with_uncond_GAN(i,inception_model,true_images)
        end_time = time.time()
        print(f'time used for whole experiment: {round(end_time-start_time,2)} seconds')
        print(f'current id score = {fid_score}')
        Uncond_fid_scores.append(fid_score)
# Out:
# ------------------------------------------------------------
# current experiment latent dim: 1
# Time for training GAN model: 278.3 seconds
# time used for whole experiment: 301.29 seconds
# current id score = 501.271051503148
# ------------------------------------------------------------
# current experiment latent dim: 2
# Time for training GAN model: 275.49 seconds
# time used for whole experiment: 296.97 seconds
# current id score = 206.92308650834772
# ------------------------------------------------------------
# current experiment latent dim: 4
# Time for training GAN model: 282.59 seconds
# time used for whole experiment: 303.17 seconds
# current id score = 190.78455126350877
# ------------------------------------------------------------
# current experiment latent dim: 6
# Time for training GAN model: 423.94 seconds
# time used for whole experiment: 447.25 seconds
# current id score = 71.32215379965015
# ------------------------------------------------------------
# current experiment latent dim: 8
# Time for training GAN model: 458.91 seconds
# time used for whole experiment: 477.29 seconds
# current id score = 115.07794394829321
# ------------------------------------------------------------
# current experiment latent dim: 10
# Time for training GAN model: 254.21 seconds
# time used for whole experiment: 272.19 seconds
# current id score = 119.32019751499679
# ------------------------------------------------------------
# current experiment latent dim: 12
# Time for training GAN model: 251.42 seconds
# time used for whole experiment: 269.02 seconds
# current id score = 108.54235162999689
# ------------------------------------------------------------
# current experiment latent dim: 14
# Time for training GAN model: 256.58 seconds
# time used for whole experiment: 273.84 seconds
# current id score = 108.50328844676824
# ------------------------------------------------------------
# current experiment latent dim: 16
# Time for training GAN model: 281.14 seconds
# time used for whole experiment: 300.12 seconds
# current id score = 116.28553193971311
# ------------------------------------------------------------
# current experiment latent dim: 18
# Time for training GAN model: 267.76 seconds
# time used for whole experiment: 286.18 seconds
# current id score = 99.66477444113133
# ------------------------------------------------------------
# current experiment latent dim: 20
# Time for training GAN model: 270.55 seconds
# time used for whole experiment: 289.2 seconds
# current id score = 99.17128650466799
# ------------------------------------------------------------
# current experiment latent dim: 22
# Time for training GAN model: 314.55 seconds
# time used for whole experiment: 335.49 seconds
# current id score = 105.57174468914802
# ------------------------------------------------------------
# current experiment latent dim: 24
# Time for training GAN model: 339.01 seconds
# time used for whole experiment: 359.34 seconds
# current id score = 118.13405271447044
# ------------------------------------------------------------
# current experiment latent dim: 26
# Time for training GAN model: 330.79 seconds
# time used for whole experiment: 352.08 seconds
# current id score = 124.96202584047072
# ------------------------------------------------------------
# current experiment latent dim: 28
# Time for training GAN model: 332.03 seconds
# time used for whole experiment: 352.62 seconds
# current id score = 113.36234238902549
# ------------------------------------------------------------
# current experiment latent dim: 30
# Time for training GAN model: 326.49 seconds
# time used for whole experiment: 347.9 seconds
# current id score = 112.38677731456744
# ------------------------------------------------------------
# current experiment latent dim: 32
# Time for training GAN model: 327.05 seconds
# time used for whole experiment: 348.0 seconds
# current id score = 101.30318300273373
# ------------------------------------------------------------
# current experiment latent dim: 34
# Time for training GAN model: 333.06 seconds
# time used for whole experiment: 354.27 seconds
# current id score = 141.68238449532012
# ------------------------------------------------------------
# current experiment latent dim: 36
# Time for training GAN model: 337.91 seconds
# time used for whole experiment: 358.59 seconds
# current id score = 123.09865080138565
# ------------------------------------------------------------
# current experiment latent dim: 38
# Time for training GAN model: 340.86 seconds
# time used for whole experiment: 362.24 seconds
# current id score = 104.96528088563511
# ------------------------------------------------------------
# current experiment latent dim: 40
# Time for training GAN model: 333.11 seconds
# time used for whole experiment: 352.82 seconds
# current id score = 94.824340847614
# ------------------------------------------------------------
# current experiment latent dim: 42
# Time for training GAN model: 328.68 seconds
# time used for whole experiment: 350.33 seconds
# current id score = 145.00534125715006
# ------------------------------------------------------------
# current experiment latent dim: 44
# Time for training GAN model: 333.38 seconds
# time used for whole experiment: 354.92 seconds
# current id score = 115.78073790691225
# ------------------------------------------------------------
# current experiment latent dim: 46
# Time for training GAN model: 335.84 seconds
# time used for whole experiment: 357.16 seconds
# current id score = 91.53775199657531
# ------------------------------------------------------------
# current experiment latent dim: 48
# Time for training GAN model: 289.55 seconds
# time used for whole experiment: 307.07 seconds
# current id score = 85.01632635208553
# ------------------------------------------------------------
# current experiment latent dim: 50
# Time for training GAN model: 250.85 seconds
# time used for whole experiment: 268.79 seconds
# current id score = 115.76116657180145
# ------------------------------------------------------------
# current experiment latent dim: 52
# Time for training GAN model: 253.57 seconds
# time used for whole experiment: 274.07 seconds
# current id score = 93.54543188160186
# ------------------------------------------------------------
# current experiment latent dim: 54
# Time for training GAN model: 261.45 seconds
# time used for whole experiment: 278.4 seconds
# current id score = 98.89509452353838
# ------------------------------------------------------------
# current experiment latent dim: 56
# Time for training GAN model: 249.98 seconds
# time used for whole experiment: 266.53 seconds
# current id score = 121.08915438241567
# ------------------------------------------------------------
# current experiment latent dim: 58
# Time for training GAN model: 250.34 seconds
# time used for whole experiment: 267.71 seconds
# current id score = 106.60086269250372
# ------------------------------------------------------------
# current experiment latent dim: 60
# Time for training GAN model: 254.92 seconds
# time used for whole experiment: 272.74 seconds
# current id score = 133.2771984105581
# ------------------------------------------------------------
# current experiment latent dim: 62
# Time for training GAN model: 254.98 seconds
# time used for whole experiment: 272.26 seconds
# current id score = 89.56204836459362
# ------------------------------------------------------------
# current experiment latent dim: 64
# Time for training GAN model: 257.39 seconds
# time used for whole experiment: 275.15 seconds
# current id score = 81.99615938324334
# ------------------------------------------------------------
# current experiment latent dim: 66
# Time for training GAN model: 254.77 seconds
# time used for whole experiment: 272.34 seconds
# current id score = 99.80806965290984
# ------------------------------------------------------------
# current experiment latent dim: 68
# Time for training GAN model: 253.41 seconds
# time used for whole experiment: 270.87 seconds
# current id score = 96.48369153722126
# ------------------------------------------------------------
# current experiment latent dim: 70
# Time for training GAN model: 253.86 seconds
# time used for whole experiment: 271.29 seconds
# current id score = 93.662308195103
# ------------------------------------------------------------
# current experiment latent dim: 72
# Time for training GAN model: 259.3 seconds
# time used for whole experiment: 276.19 seconds
# current id score = 107.95303898238443
# ------------------------------------------------------------
# current experiment latent dim: 74
# Time for training GAN model: 269.58 seconds
# time used for whole experiment: 288.83 seconds
# current id score = 112.66186857935335
# ------------------------------------------------------------
# current experiment latent dim: 76
# Time for training GAN model: 260.25 seconds
# time used for whole experiment: 278.98 seconds
# current id score = 111.27976095133529
# ------------------------------------------------------------
# current experiment latent dim: 78
# Time for training GAN model: 258.62 seconds
# time used for whole experiment: 277.73 seconds
# current id score = 91.84538781189887
# ------------------------------------------------------------
# current experiment latent dim: 80
# Time for training GAN model: 258.92 seconds
# time used for whole experiment: 277.71 seconds
# current id score = 79.04473610751572
# ------------------------------------------------------------
# current experiment latent dim: 82
# Time for training GAN model: 258.8 seconds
# time used for whole experiment: 277.68 seconds
# current id score = 95.31243437894528
# ------------------------------------------------------------
# current experiment latent dim: 84
# Time for training GAN model: 259.58 seconds
# time used for whole experiment: 278.44 seconds
# current id score = 80.54680254472301
# ------------------------------------------------------------
# current experiment latent dim: 86
# Time for training GAN model: 263.24 seconds
# time used for whole experiment: 281.85 seconds
# current id score = 81.0653738421277
# ------------------------------------------------------------
# current experiment latent dim: 88
# Time for training GAN model: 262.77 seconds
# time used for whole experiment: 281.59 seconds
# current id score = 86.3731607065371
# ------------------------------------------------------------
# current experiment latent dim: 90
# Time for training GAN model: 262.61 seconds
# time used for whole experiment: 281.2 seconds
# current id score = 99.97573491900889
# ------------------------------------------------------------
# current experiment latent dim: 92
# Time for training GAN model: 259.64 seconds
# time used for whole experiment: 278.34 seconds
# current id score = 72.99919118940329
# ------------------------------------------------------------
# current experiment latent dim: 94
# Time for training GAN model: 259.78 seconds
# time used for whole experiment: 277.36 seconds
# current id score = 118.655257730032
# ------------------------------------------------------------
# current experiment latent dim: 96
# Time for training GAN model: 263.64 seconds
# time used for whole experiment: 282.49 seconds
# current id score = 138.6013010650127
# ------------------------------------------------------------
# current experiment latent dim: 98
# Time for training GAN model: 274.13 seconds
# time used for whole experiment: 292.87 seconds
# current id score = 99.60984502746237
# ------------------------------------------------------------
# current experiment latent dim: 100
# Time for training GAN model: 262.25 seconds
# time used for whole experiment: 279.86 seconds
# current id score = 86.33222899533071
# ------------------------------------------------------------
# current experiment latent dim: 102
# Time for training GAN model: 260.66 seconds
# time used for whole experiment: 279.58 seconds
# current id score = 93.35173258151502
# ------------------------------------------------------------
# current experiment latent dim: 104
# Time for training GAN model: 260.83 seconds
# time used for whole experiment: 279.5 seconds
# current id score = 112.47842610471476
# ------------------------------------------------------------
# current experiment latent dim: 106
# Time for training GAN model: 263.43 seconds
# time used for whole experiment: 282.29 seconds
# current id score = 86.65081758115116
# ------------------------------------------------------------
# current experiment latent dim: 108
# Time for training GAN model: 260.2 seconds
# time used for whole experiment: 279.04 seconds
# current id score = 75.68751159371281
# ------------------------------------------------------------
# current experiment latent dim: 110
# Time for training GAN model: 264.1 seconds
# time used for whole experiment: 283.06 seconds
# current id score = 94.07038366880752
# ------------------------------------------------------------
# current experiment latent dim: 112
# Time for training GAN model: 265.23 seconds
# time used for whole experiment: 282.85 seconds
# current id score = 143.06017634095042
# ------------------------------------------------------------
# current experiment latent dim: 114
# Time for training GAN model: 264.94 seconds
# time used for whole experiment: 283.55 seconds
# current id score = 81.42250510721883
# ------------------------------------------------------------
# current experiment latent dim: 116
# Time for training GAN model: 265.28 seconds
# time used for whole experiment: 284.19 seconds
# current id score = 94.4252073465272
# ------------------------------------------------------------
# current experiment latent dim: 118
# Time for training GAN model: 262.44 seconds
# time used for whole experiment: 281.24 seconds
# current id score = 102.76189760117548
# ------------------------------------------------------------
# current experiment latent dim: 120
# Time for training GAN model: 260.75 seconds
# time used for whole experiment: 279.99 seconds
# current id score = 135.4576263954573
# ------------------------------------------------------------
# current experiment latent dim: 122
# Time for training GAN model: 265.63 seconds
# time used for whole experiment: 284.21 seconds
# current id score = 78.53135745906783
# ------------------------------------------------------------
# current experiment latent dim: 124
# Time for training GAN model: 266.45 seconds
# time used for whole experiment: 285.31 seconds
# current id score = 100.9383254069954
# ------------------------------------------------------------
# current experiment latent dim: 126
# Time for training GAN model: 268.37 seconds
# time used for whole experiment: 287.08 seconds
# current id score = 78.97834317765415
# ------------------------------------------------------------
# current experiment latent dim: 128
# Time for training GAN model: 267.31 seconds
# time used for whole experiment: 286.24 seconds
# current id score = 91.26672734513477

# %%
plt.plot(range(0,129,2), fid_scores,c = 'g' ,label = 'CGan generated FID')
plt.axhline(np.mean(fid_socre_between_true), color = 'r', label = 'True Image FID')
plt.plot(range(0,129,2),Uncond_fid_scores, color = 'b', label = 'UncondGan generated FID')
plt.title('Latent dim and FID score')
plt.xlabel('Latent dim')
plt.ylabel('FID score')
plt.legend()
plt.show()

# %%
# to save experiment time, latent dim increased by 2
fid_scores_before_20 = []
for i in range(0,20):
        print('-'*60)
        print(f'current experiment latent dim: {i}')
        start_time = time.time()
        fid_score = run_a_experiment_with_fixed_dim(i,inception_model,true_images)
        end_time = time.time()
        print(f'time used for whole experiment: {round(end_time-start_time,2)} seconds')
        print(f'current id score = {fid_score}')
        fid_scores_before_20.append(fid_score)
# Out:
# ------------------------------------------------------------
# current experiment latent dim: 0
# Time for training GAN model: 329.33 seconds
# time used for whole experiment: 350.28 seconds
# current id score = 653.8850280780812
# ------------------------------------------------------------
# current experiment latent dim: 1
# Time for training GAN model: 334.45 seconds
# time used for whole experiment: 356.37 seconds
# current id score = 330.99759515779846
# ------------------------------------------------------------
# current experiment latent dim: 2
# Time for training GAN model: 334.48 seconds
# time used for whole experiment: 354.36 seconds
# current id score = 191.03662464500047
# ------------------------------------------------------------
# current experiment latent dim: 3
# Time for training GAN model: 332.51 seconds
# time used for whole experiment: 351.65 seconds
# current id score = 88.95467044400478
# ------------------------------------------------------------
# current experiment latent dim: 4
# Time for training GAN model: 339.57 seconds
# time used for whole experiment: 358.44 seconds
# current id score = 104.18020552324722
# ------------------------------------------------------------
# current experiment latent dim: 5
# Time for training GAN model: 327.3 seconds
# time used for whole experiment: 347.54 seconds
# current id score = 120.81169672308813
# ------------------------------------------------------------
# current experiment latent dim: 6
# Time for training GAN model: 331.01 seconds
# time used for whole experiment: 350.04 seconds
# current id score = 71.52699033086384
# ------------------------------------------------------------
# current experiment latent dim: 7
# Time for training GAN model: 327.41 seconds
# time used for whole experiment: 346.54 seconds
# current id score = 69.4224222720369
# ------------------------------------------------------------
# current experiment latent dim: 8
# Time for training GAN model: 326.57 seconds
# time used for whole experiment: 345.82 seconds
# current id score = 89.34042409610352
# ------------------------------------------------------------
# current experiment latent dim: 9
# Time for training GAN model: 326.61 seconds
# time used for whole experiment: 346.13 seconds
# current id score = 50.91703314692827
# ------------------------------------------------------------
# current experiment latent dim: 10
# Time for training GAN model: 328.83 seconds
# time used for whole experiment: 349.11 seconds
# current id score = 97.74870686642895
# ------------------------------------------------------------
# current experiment latent dim: 11
# Time for training GAN model: 338.43 seconds
# time used for whole experiment: 358.46 seconds
# current id score = 78.92708633490393
# ------------------------------------------------------------
# current experiment latent dim: 12
# Time for training GAN model: 336.76 seconds
# time used for whole experiment: 355.86 seconds
# current id score = 48.910274499712
# ------------------------------------------------------------
# current experiment latent dim: 13
# Time for training GAN model: 328.32 seconds
# time used for whole experiment: 347.43 seconds
# current id score = 75.27049084417698
# ------------------------------------------------------------
# current experiment latent dim: 14
# Time for training GAN model: 327.59 seconds
# time used for whole experiment: 346.5 seconds
# current id score = 84.64284490668629
# ------------------------------------------------------------
# current experiment latent dim: 15
# Time for training GAN model: 329.56 seconds
# time used for whole experiment: 348.48 seconds
# current id score = 61.65187691167369
# ------------------------------------------------------------
# current experiment latent dim: 16
# Time for training GAN model: 328.9 seconds
# time used for whole experiment: 347.76 seconds
# current id score = 72.45288158932334
# ------------------------------------------------------------
# current experiment latent dim: 17
# Time for training GAN model: 329.83 seconds
# time used for whole experiment: 348.79 seconds
# current id score = 48.8979374033006
# ------------------------------------------------------------
# current experiment latent dim: 18
# Time for training GAN model: 327.1 seconds
# time used for whole experiment: 344.99 seconds
# current id score = 65.57705075250587
# ------------------------------------------------------------
# current experiment latent dim: 19
# Time for training GAN model: 329.24 seconds
# time used for whole experiment: 347.1 seconds
# current id score = 51.9098678715192

# %%
Uncond_fid_scores_before_20 = []
for i in range(1,20):
    print('-'*60)
    print(f'current experiment latent dim: {i}')
    start_time = time.time()
    fid_score = run_a_experiment_with_uncond_GAN(i,inception_model,true_images)
    end_time = time.time()
    print(f'time used for whole experiment: {round(end_time-start_time,2)} seconds')
    print(f'current id score = {fid_score}')
    Uncond_fid_scores_before_20.append(fid_score)
# Out:
# ------------------------------------------------------------
# current experiment latent dim: 1
# Time for training GAN model: 254.2 seconds
# time used for whole experiment: 273.72 seconds
# current id score = 751.1722032493899
# ------------------------------------------------------------
# current experiment latent dim: 2
# Time for training GAN model: 253.75 seconds
# time used for whole experiment: 272.51 seconds
# current id score = 214.0923981614655
# ------------------------------------------------------------
# current experiment latent dim: 3
# Time for training GAN model: 252.58 seconds
# time used for whole experiment: 271.46 seconds
# current id score = 168.57476229497868
# ------------------------------------------------------------
# current experiment latent dim: 4
# Time for training GAN model: 252.8 seconds
# time used for whole experiment: 271.76 seconds
# current id score = 162.6246526068109
# ------------------------------------------------------------
# current experiment latent dim: 5
# Time for training GAN model: 253.44 seconds
# time used for whole experiment: 272.39 seconds
# current id score = 112.85838474704158
# ------------------------------------------------------------
# current experiment latent dim: 6
# Time for training GAN model: 251.75 seconds
# time used for whole experiment: 271.11 seconds
# current id score = 127.73533993678925
# ------------------------------------------------------------
# current experiment latent dim: 7
# Time for training GAN model: 252.1 seconds
# time used for whole experiment: 270.13 seconds
# current id score = 95.94350438782466
# ------------------------------------------------------------
# current experiment latent dim: 8
# Time for training GAN model: 252.48 seconds
# time used for whole experiment: 273.01 seconds
# current id score = 88.0166098147041
# ------------------------------------------------------------
# current experiment latent dim: 9
# Time for training GAN model: 262.75 seconds
# time used for whole experiment: 282.99 seconds
# current id score = 94.62972974639614
# ------------------------------------------------------------
# current experiment latent dim: 10
# Time for training GAN model: 256.07 seconds
# time used for whole experiment: 276.51 seconds
# current id score = 131.36273738252467
# ------------------------------------------------------------
# current experiment latent dim: 11
# Time for training GAN model: 258.24 seconds
# time used for whole experiment: 277.43 seconds
# current id score = 116.30297244045056
# ------------------------------------------------------------
# current experiment latent dim: 12
# Time for training GAN model: 255.78 seconds
# time used for whole experiment: 274.87 seconds
# current id score = 62.835669360647664
# ------------------------------------------------------------
# current experiment latent dim: 13
# Time for training GAN model: 254.78 seconds
# time used for whole experiment: 274.75 seconds
# current id score = 98.04358137667481
# ------------------------------------------------------------
# current experiment latent dim: 14
# Time for training GAN model: 263.94 seconds
# time used for whole experiment: 282.91 seconds
# current id score = 90.8500064315435
# ------------------------------------------------------------
# current experiment latent dim: 15
# Time for training GAN model: 256.98 seconds
# time used for whole experiment: 276.16 seconds
# current id score = 91.730221922862
# ------------------------------------------------------------
# current experiment latent dim: 16
# Time for training GAN model: 265.27 seconds
# time used for whole experiment: 285.79 seconds
# current id score = 89.18945568998079
# ------------------------------------------------------------
# current experiment latent dim: 17
# Time for training GAN model: 257.34 seconds
# time used for whole experiment: 276.69 seconds
# current id score = 97.09063977916796
# ------------------------------------------------------------
# current experiment latent dim: 18
# Time for training GAN model: 255.7 seconds
# time used for whole experiment: 274.84 seconds
# current id score = 114.66158474227508
# ------------------------------------------------------------
# current experiment latent dim: 19
# Time for training GAN model: 253.91 seconds
# time used for whole experiment: 273.05 seconds
# current id score = 113.95602243755269

# %%
plt.plot(range(1,20),fid_scores_before_20[1:] ,c = 'g' ,label = 'CGan generated FID')
plt.axhline(np.mean(fid_socre_between_true), color = 'r', label = 'True Image FID')
plt.plot(range(1,20),Uncond_fid_scores_before_20, color = 'b', label = 'UncondGan generated FID')
plt.title('Latent dim and FID score')
plt.xlabel('Latent dim')
plt.ylabel('FID score')
plt.legend()
plt.show()

# %%
table = pd.DataFrame({
    'fid_score':fid_scores_before_20
})
table.to_csv('fid_list_20.csv')

# %%
table = pd.DataFrame({
    'fid_score':Uncond_fid_scores_before_20
})
table.to_csv('fid_list_UNCONDgan_20.csv')
